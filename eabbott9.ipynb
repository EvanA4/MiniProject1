# %% [markdown]
# # Evan Abbott's Notebook
#
# ## Goal
# - Make issue on team member's repository
# - Respond to team member's issue on my repository
# - Answer the following question: which genres use longer words?
#
# ## Methods
# - Find five popular books in each of four genres (20 total)
#     - Using Gutenberg's book search
#     - [Children's](https://www.gutenberg.org/ebooks/bookshelf/636):
#         - [Alice's Adventures in Wonderland](https://www.gutenberg.org/cache/epub/11/pg11-images.html)
#         - [Little Women; Or, Meg, Jo, Beth, and Amy](https://www.gutenberg.org/cache/epub/37106/pg37106-images.html)
#         - [The Rover Boys on the Farm; or, Last Days at Putnam Hall](https://www.gutenberg.org/cache/epub/22163/pg22163-images.html)
#         - [The Camp Fire Girls Solve a Mystery; Or, The Christmas Adventure at Carver…](https://www.gutenberg.org/cache/epub/38983/pg38983-images.html)
#         - [The Wonderful Wizard of Oz](https://www.gutenberg.org/cache/epub/55/pg55-images.html)
#     - [Mystery](https://www.gutenberg.org/ebooks/bookshelf/640):
#         - [Crime and Punishment](https://www.gutenberg.org/cache/epub/2554/pg2554-images.html)
#         - [The Secret of Chimneys](https://www.gutenberg.org/cache/epub/65238/pg65238-images.html)
#         - [The Adventures of Sherlock Holmes](https://www.gutenberg.org/cache/epub/1661/pg1661-images.html)
#         - [The Mysteries of Udolpho](https://www.gutenberg.org/ebooks/3268)
#         - [Carmen](https://www.gutenberg.org/cache/epub/2465/pg2465-images.html)
#     - [Adventure](https://www.gutenberg.org/ebooks/bookshelf/644):
#         - [Moby Dick; Or, The Whale](https://www.gutenberg.org/cache/epub/2701/pg2701-images.html)
#         - [The Man Who Was Thursday: A Nightmare](https://www.gutenberg.org/cache/epub/1695/pg1695-images.html)
#         - [The Extraordinary Adventures of Arsène Lupin, Gentleman-Burglar](https://www.gutenberg.org/cache/epub/6133/pg6133-images.html)
#         - [The Book of the Thousand Nights and a Night](https://www.gutenberg.org/cache/epub/51252/pg51252-images.html)
#         - [The Misplaced Battleship](https://www.gutenberg.org/cache/epub/22541/pg22541-images.html)
#     - [Fantasy](https://www.gutenberg.org/ebooks/bookshelf/638):
#         - [Dracula](https://www.gutenberg.org/cache/epub/345/pg345-images.html)
#         - [The King in Yellow](https://www.gutenberg.org/cache/epub/8492/pg8492-images.html)
#         - [Frankenstein; or, the modern prometheus](https://www.gutenberg.org/cache/epub/84/pg84-images.html)
#         - [The call of Cthulhu](https://www.gutenberg.org/cache/epub/68283/pg68283-images.html)
#         - [The House on the Borderland](https://www.gutenberg.org/cache/epub/10002/pg10002-images.html)
# - Find the word frequencies of these texts
# - Determine average word length of these texts
# - Generate bar graphs comparing the average word lengths of different genres
# - Interpret to answer the question: which genres use longer words?

# %% [markdown]
# ## Part 1: Defining Metadata
#
# A dictionary is defined, mapping genres to lists of tuples. Each tuple represents a book via its title, author(s), and URL.

# %%
METADATA = {
    "Children's": [
        (
            "Alice's Adventures in Wonderland",
            "Lewis Carroll",
            "https://www.gutenberg.org/cache/epub/11/pg11-images.html",
        ),
        (
            "Little Women; Or, Meg, Jo, Beth, and Amy",
            "Louisa May Alcott",
            "https://www.gutenberg.org/cache/epub/37106/pg37106-images.html",
        ),
        (
            "The Rover Boys on the Farm; or, Last Days at Putnam Hall",
            "Arthur M. Winfield",
            "https://www.gutenberg.org/cache/epub/22163/pg22163-images.html",
        ),
        (
            "The Camp Fire Girls Solve a Mystery; Or, The Christmas Adventure at Carver House",
            "Hildegard G. Frey",
            "https://www.gutenberg.org/cache/epub/38983/pg38983-images.html",
        ),
        (
            "The Wonderful Wizard of Oz",
            "L. Frank Baum",
            "https://www.gutenberg.org/cache/epub/55/pg55-images.html",
        ),
    ],
    "Mystery": [
        (
            "Crime and Punishment",
            "Fyodor Dostoevsky",
            "https://www.gutenberg.org/cache/epub/2554/pg2554-images.html",
        ),
        (
            "The Secret of Chimneys",
            "Agatha Christie",
            "https://www.gutenberg.org/cache/epub/65238/pg65238-images.html",
        ),
        (
            "The Adventures of Sherlock Holmes",
            "Arthur Conan Doyle",
            "https://www.gutenberg.org/cache/epub/1661/pg1661-images.html",
        ),
        (
            "The Mysteries of Udolpho",
            "Ann Radcliffe",
            "https://www.gutenberg.org/cache/epub/3268/pg3268-images.html",
        ),
        (
            "Carmen",
            "Prosper Mérimée",
            "https://www.gutenberg.org/cache/epub/2465/pg2465-images.html",
        ),
    ],
    "Adventure": [
        (
            "Moby Dick; Or, The Whale",
            "Herman Melville",
            "https://www.gutenberg.org/cache/epub/2701/pg2701-images.html",
        ),
        (
            "The Man Who Was Thursday: A Nightmare",
            "G. K. Chesterton",
            "https://www.gutenberg.org/cache/epub/1695/pg1695-images.html",
        ),
        (
            "The Extraordinary Adventures of Arsène Lupin, Gentleman-Burglar",
            "Maurice Leblanc",
            "https://www.gutenberg.org/cache/epub/6133/pg6133-images.html",
        ),
        (
            "The Book of the Thousand Nights and a Night",
            "Richard Francis Burton",
            "https://www.gutenberg.org/cache/epub/51252/pg51252-images.html",
        ),
        (
            "The Misplaced Battleship",
            "Harry Harrison",
            "https://www.gutenberg.org/cache/epub/22541/pg22541-images.html",
        ),
    ],
    "Fantasy": [
        (
            "Dracula",
            "Bram Stoker",
            "https://www.gutenberg.org/cache/epub/345/pg345-images.html",
        ),
        (
            "The King in Yellow",
            "Robert W. Chambers",
            "https://www.gutenberg.org/cache/epub/8492/pg8492-images.html",
        ),
        (
            "Frankenstein; or, the Modern Prometheus",
            "Mary Shelley",
            "https://www.gutenberg.org/cache/epub/84/pg84-images.html",
        ),
        (
            "The Call of Cthulhu",
            "H. P. Lovecraft",
            "https://www.gutenberg.org/cache/epub/68283/pg68283-images.html",
        ),
        (
            "The House on the Borderland",
            "William Hope Hodgson",
            "https://www.gutenberg.org/cache/epub/10002/pg10002-images.html",
        ),
    ],
}

num_books = 0
for genre in METADATA:
    print(f"Loaded genre: {genre}:")
    for book in METADATA[genre]:
        print(f"\t\"{book[0]}\" by {book[1]}")
        num_books += 1
# Out:
# Loaded genre: Children's:
# 	"Alice's Adventures in Wonderland" by Lewis Carroll
# 	"Little Women; Or, Meg, Jo, Beth, and Amy" by Louisa May Alcott
# 	"The Rover Boys on the Farm; or, Last Days at Putnam Hall" by Arthur M. Winfield
# 	"The Camp Fire Girls Solve a Mystery; Or, The Christmas Adventure at Carver House" by Hildegard G. Frey
# 	"The Wonderful Wizard of Oz" by L. Frank Baum
# Loaded genre: Mystery:
# 	"Crime and Punishment" by Fyodor Dostoevsky
# 	"The Secret of Chimneys" by Agatha Christie
# 	"The Adventures of Sherlock Holmes" by Arthur Conan Doyle
# 	"The Mysteries of Udolpho" by Ann Radcliffe
# 	"Carmen" by Prosper Mérimée
# Loaded genre: Adventure:
# 	"Moby Dick; Or, The Whale" by Herman Melville
# 	"The Man Who Was Thursday: A Nightmare" by G. K. Chesterton
# 	"The Extraordinary Adventures of Arsène Lupin, Gentleman-Burglar" by Maurice Leblanc
# 	"The Book of the Thousand Nights and a Night" by Richard Francis Burton
# 	"The Misplaced Battleship" by Harry Harrison
# ...

# %% [markdown]
# # Part 2: Computing Average Word Lengths
#
# `MiniProject1.ipynb`'s utility functions are redeclared in this notebook in the cell below. Then, the average word length is computed for each book, and its value is added to its corresponding genre's list.

# %%
import requests, re, nltk
from bs4 import BeautifulSoup
from nltk import clean_html
from collections import Counter
import operator

nltk.download('stopwords')

# utility functions and variables from MiniProject1.ipynb
stop_words = nltk.corpus.stopwords.words('english') + [
 'ut', '\'re','.', ',', '--', '\'s', '?', ')', '(', ':', '\'',
 '\"', '-', '}', '{', '&', '|', u'\u2014' ]

def cleanHtml (html):
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')
    return soup .get_text()

def cleanWord (w):
    wn = re.sub('[,"\\.\'&\\|:@>*;/=]', "", w)
    return re.sub('^[0-9\\.]*$', "", wn)
       
def get_wf (URL):
    r = requests .get(URL)
    t = cleanHtml (r .text) .lower()
    wds = re .split('\\s+',t)
    for i in range(len(wds)):
        wds [i] = cleanWord (wds [i])
    wf = Counter (wds)
    for k in stop_words:
        wf. pop(k, None)
    tw = 0
    for w in wf:
       tw += wf[w]
    wfs = [x for x in sorted(wf .items(), key = operator.itemgetter(1)) if x[0] != ''] # modified to remove empty string
    return (wfs[:][::-1], tw)

(wf_ee, tw_ee) = get_wf('https://www.gutenberg.org/cache/epub/14838/pg14838-images.html')

print(wf_ee[:5])
print(tw_ee)
# Out:
# [('project', 84), ('gutenberg', 66), ('work', 46), ('works', 32), ('peter', 28)]
# 2242
# [nltk_data] Downloading package stopwords to /home/evana/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
import math
import os
from time import sleep

genres_awl = {}
genres_wc = {}

# iterate through of the books
ctr = 0
for genre in METADATA:
    genres_awl[genre] = []
    genres_wc[genre] = []
    for title, authors, url in METADATA[genre]:
        print(f"({math.ceil(ctr * 100 / num_books)}%) Processing \"{title}\" by {authors}...".ljust(150, " "), end='\r')

        # start computing and storing statistics
        word_freqs, total_word_count = get_wf(url)
        weighted_sum = 0
        for word, word_count in word_freqs:
            weighted_sum += len(word) * word_count / total_word_count
        genres_awl[genre].append(weighted_sum)
        genres_wc[genre].append(total_word_count)

        ctr += 1

print("(100%) Finished processing books!".ljust(100, " "))
# Out:
# (100%) Finished processing books!

# %% [markdown]
# ## Part 3: Graphing Results
#
# Genres are plotted against their average word lengths and word counts for a visibly intuitive result. The word frequencies of the most commonly downloaded children's and mystery books are also compared.

# %%
import numpy as np
import matplotlib.pyplot as plt

genres = [genre for genre in METADATA]
values = [np.mean(genres_awl[genre]) for genre in genres]
errors = [np.std(genres_awl[genre]) for genre in genres]

# Create bar chart with error bars
plt.figure(figsize=(8, 6))
plt.bar(genres, values, yerr=errors, capsize=8)

# Add labels and title
plt.title('Average Word Length per Book Genre', fontsize=14)
plt.xlabel('Genre')
plt.ylabel('Average Word Length')

# Show plot
plt.show()

# %%
values = [np.mean(genres_wc[genre]) for genre in genres]
errors = [np.std(genres_wc[genre]) for genre in genres]

# Create bar chart with error bars
plt.figure(figsize=(8, 6))
plt.bar(genres, values, yerr=errors, capsize=8)

# Add labels and title
plt.title('Average Word Length per Book Genre', fontsize=14)
plt.xlabel('Genre')
plt.ylabel('Average Word Length')

# Show plot
plt.show()

# %%
import pylab

def plotTwoLists (wf_ee, wf_bu, title):
    f = plt.figure (figsize=(10, 6))
    # this is painfully tedious....
    f .suptitle (title, fontsize=20)
    ax = f.add_subplot(111)
    ax .spines ['top'] .set_color ('none')
    ax .spines ['bottom'] .set_color ('none')
    ax .spines ['left'] .set_color ('none')
    ax .spines ['right'] .set_color ('none')
    ax .tick_params (labelcolor='w', top='off', bottom='off', left='off', right='off', labelsize=20)

    # Create two subplots, this is the first one
    ax1 = f .add_subplot (121)
    plt .subplots_adjust (wspace=.5)

    pos = np .arange (len(wf_ee)) 
    ax1 .tick_params (axis='both', which='major', labelsize=14)
    pylab .yticks (pos, [ x [0] for x in wf_ee ])
    ax1 .barh (range(len(wf_ee)), [ x [1] for x in wf_ee ], align='center')

    ax2 = f .add_subplot (122)
    ax2 .tick_params (axis='both', which='major', labelsize=14)
    pos = np .arange (len(wf_bu)) 
    pylab .yticks (pos, [ x [0] for x in wf_bu ])
    ax2 .barh (range (len(wf_bu)), [ x [1] for x in wf_bu ], align='center')

    plt.show()

child = METADATA["Children\'s"][0]
mystery = METADATA["Mystery"][0]
child_word_freqs, child_total_word_count = get_wf(child[2])
mystery_word_freqs, mystery_total_word_count = get_wf(mystery[2])
child_display = child_word_freqs[:13]
mystery_display = mystery_word_freqs[:13]
child_display.sort(key=lambda x: x[1], reverse=False)
mystery_display.sort(key=lambda x: x[1], reverse=False)

plotTwoLists (child_display, mystery_display, f"Difference between \"{child[0]}\" and \"{mystery[0]}\"")

# %% [markdown]
# ## Conclusion
#
# While the mystery, adventure, and fantasy genres all had very similar average word lengths, the children's genre's was significantly lower. Unsurprisingly, these results suggest that children's books often have a simpler vocabulary and often use shorter words.
#
# Interestingly, both the children's and fantasy generes had a similar average word length. The average word count for each genre comes with a high standard deviation, meaning genre is a poor predictor for total word count.
#
# As for word frequency, both stories had their main character as one of their most frequent words. Neither story seems to have notably longer words, save "Crime and Punishment"'s main character, Raskolnikov. The other common words appear to have similar lengths. One limitation to this study is that shorter stories like "Alice in Wonderland" are more susceptible to their statistics being dirtied by the Gutenberg site's header and footer. "gutenberg" can be seen as one of the most common words of the book solely due to the site's wrapper around these books.
